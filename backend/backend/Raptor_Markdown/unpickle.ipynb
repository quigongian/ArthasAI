# %%
import pickle
import pandas as pd

# %%
with open("Paper metadata.pkl", "rb") as file:
    data = pickle.load(file)
data.head(5)
# Out:
#                  id               submitter  \
# 1368259  2010.11929      Alexey Dosovitskiy
# 906286   1710.10903  Petar Veli\v{c}kovi\'c
# 267448    1106.1813            K. W. Bowyer
# 826904   1703.03400            Chelsea Finn
# 851415   1705.07874          Scott Lundberg
#
#                                                    authors  \
# 1368259  Alexey Dosovitskiy, Lucas Beyer, Alexander Kol...
# 906286   Petar Veli\v{c}kovi\'c, Guillem Cucurull, Aran...
# 267448   N. V. Chawla, K. W. Bowyer, L. O. Hall, W. P. ...
# 826904          Chelsea Finn, Pieter Abbeel, Sergey Levine
# 851415                        Scott Lundberg and Su-In Lee
#
#                                                      title  \
# 1368259  An Image is Worth 16x16 Words: Transformers fo...
# 906286                            Graph Attention Networks
# 267448   SMOTE: Synthetic Minority Over-sampling Technique
# 826904   Model-Agnostic Meta-Learning for Fast Adaptati...
# ...

# %%
# save dataframe as json
data.to_json("Paper_metadata.json", orient="records", indent=4)

# %%
data_from_json = pd.read_json("Paper_metadata.json")

# %%
data_from_json.head(5)
# Out:
#            id               submitter  \
# 0  2010.11929      Alexey Dosovitskiy
# 1  1710.10903  Petar Veli\v{c}kovi\'c
# 2   1106.1813            K. W. Bowyer
# 3  1703.03400            Chelsea Finn
# 4  1705.07874          Scott Lundberg
#
#                                              authors  \
# 0  Alexey Dosovitskiy, Lucas Beyer, Alexander Kol...
# 1  Petar Veli\v{c}kovi\'c, Guillem Cucurull, Aran...
# 2  N. V. Chawla, K. W. Bowyer, L. O. Hall, W. P. ...
# 3         Chelsea Finn, Pieter Abbeel, Sergey Levine
# 4                       Scott Lundberg and Su-In Lee
#
#                                                title  \
# 0  An Image is Worth 16x16 Words: Transformers fo...
# 1                           Graph Attention Networks
# 2  SMOTE: Synthetic Minority Over-sampling Technique
# 3  Model-Agnostic Meta-Learning for Fast Adaptati...
# 4  A Unified Approach to Interpreting Model Predi...
#
#                                             comments  \
# ...
